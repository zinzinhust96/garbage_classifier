# %% [markdown]
# ### Step 1: Download 3 datasets. Add number labels (1, 2, 3) to each dataset.

# %% [markdown]
# ### Step 2: Rename the images in each dataset to have the dataset number as a suffix.
# (e.g. cardboard1_1.jpg, cardboard1_2.jpg, cardboard2_1.jpg, etc.)

# %%
import os
import shutil

SRC_PATH = "data/archive/wanglei1220_data"
TRG_PATH = "data/archive/wanglei1220_data_renamed"
os.makedirs(TRG_PATH, exist_ok=True)

dataset_index = os.path.basename(SRC_PATH).split("_")[0]
for class_name in os.listdir(SRC_PATH):
    print(class_name)
    os.makedirs(os.path.join(TRG_PATH, class_name), exist_ok=True)
    for i, file_name in enumerate(os.listdir(os.path.join(SRC_PATH, class_name))):
        basename, ext = file_name.split(".")
        new_name = f"{basename}_data{dataset_index}.{ext}"
        shutil.copy(os.path.join(SRC_PATH, class_name, file_name), os.path.join(TRG_PATH, class_name, new_name))
# Out:
# metal

# %% [markdown]
# ### Step 3: Merge the 3 datasets into a single dataset.
# There are 5 classes:
# - cardboard_paper
# - metal
# - plastic
# - glass
# - others: battery, biological, clothes, shoes, trash

# %%
MERGE_PATH = "data/merged"
os.makedirs(MERGE_PATH, exist_ok=True)

classes_list = ["cardboard_paper", "metal", "plastic", "glass", "battery", "biological", "clothes", "shoes", "trash"]
for class_name in classes_list:
    os.makedirs(os.path.join(MERGE_PATH, class_name), exist_ok=True)
    
data_list = [
    "data/1_garbage_classification_renamed",
    "data/2_garbage-dataset_renamed",
    "data/3_TrashType_Image_Dataset_renamed",
    "data/yolo_data"
]

for data_path in data_list:
    print(data_path)
    for class_name in os.listdir(data_path):
        if "glass" in class_name:
            # copy that folder content to `glass` folder
            for file_name in os.listdir(os.path.join(data_path, class_name)):
                shutil.copy(os.path.join(data_path, class_name, file_name), os.path.join(MERGE_PATH, "glass", file_name))
        elif class_name in "cardboard_paper":
            # copy that folder content to `cardboard_paper` folder
            for file_name in os.listdir(os.path.join(data_path, class_name)):
                shutil.copy(os.path.join(data_path, class_name, file_name), os.path.join(MERGE_PATH, "cardboard_paper", file_name))
        else:
            # copy that folder content to corresponding folder
            for file_name in os.listdir(os.path.join(data_path, class_name)):
                shutil.copy(os.path.join(data_path, class_name, file_name), os.path.join(MERGE_PATH, class_name, file_name))
# Out:
# data/1_garbage_classification_renamed
# data/2_garbage-dataset_renamed
# data/3_TrashType_Image_Dataset_renamed
# data/yolo_data

# %% [markdown]
# ### Step 4: check and remove duplicated images

# %%
import os
import imagehash
from PIL import Image

def find_and_remove_duplicates(folder_path):
    # Dictionary to store unique image hashes and their file paths
    hash_dict = {}

    # Iterate over all files in the folder
    for filename in os.listdir(folder_path):
        file_path = os.path.join(folder_path, filename)
        
        # Check if the file is an image (you can add more image types if needed)
        if filename.lower().endswith(('.png', '.jpg', '.jpeg', '.bmp', '.gif')):
            try:
                # Open the image and calculate its perceptual hash
                with Image.open(file_path) as img:
                    img_hash = imagehash.phash(img)
                
                # If this hash is already in hash_dict, it means we found a duplicate
                if img_hash in hash_dict:
                    print(f"Duplicate found: {filename} is a duplicate of {hash_dict[img_hash]}")
                    os.remove(file_path)  # Remove the duplicate image
                else:
                    # If unique, add the hash and file path to the dictionary
                    hash_dict[img_hash] = file_path
            except Exception as e:
                print(f"Error processing file {filename}: {e}")

# Specify the path to the folder containing images
folder_path = '/home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash'
find_and_remove_duplicates(folder_path)
# Out:
# Duplicate found: trash186_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_734_data2.jpg
# Duplicate found: trash278_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_280_data2.jpg
# Duplicate found: trash_584_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash62_data1.jpg
# Duplicate found: trash_355_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash453_data1.jpg
# Duplicate found: trash_737_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash64_data1.jpg
# Duplicate found: trash_203_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash250_data1.jpg
# Duplicate found: trash157_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_388_data2.jpg
# Duplicate found: trash_155_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash69_data1.jpg
# Duplicate found: trash_834_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_057_data3.jpg
# Duplicate found: trash_143_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_028_data3.jpg
# Duplicate found: trash_226_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash418_data1.jpg
# Duplicate found: trash52_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_26_data2.jpg
# Duplicate found: trash48_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_367_data2.jpg
# Duplicate found: trash42_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_6_data2.jpg
# Duplicate found: trash_759_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash96_data1.jpg
# Duplicate found: trash_382_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_019_data3.jpg
# Duplicate found: trash_287_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash401_data1.jpg
# Duplicate found: trash_385_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_106_data3.jpg
# Duplicate found: trash_788_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash114_data1.jpg
# Duplicate found: trash_316_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash406_data1.jpg
# Duplicate found: trash607_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_125_data2.jpg
# Duplicate found: trash_674_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash626_data1.jpg
# Duplicate found: trash_587_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash180_data1.jpg
# Duplicate found: trash_724_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash188_data1.jpg
# Duplicate found: trash39_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_166_data2.jpg
# Duplicate found: trash175_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_95_data2.jpg
# Duplicate found: trash324_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_361_data2.jpg
# Duplicate found: trash_111_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash424_data1.jpg
# Duplicate found: trash331_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_690_data2.jpg
# Duplicate found: trash_670_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash371_data1.jpg
# Duplicate found: trash_132_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_692_data2.jpg
# Duplicate found: trash_741_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_086_data3.jpg
# Duplicate found: trash109_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_746_data2.jpg
# Duplicate found: trash148_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_30_data2.jpg
# Duplicate found: trash_098_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_521_data2.jpg
# Duplicate found: trash28_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_565_data2.jpg
# Duplicate found: trash205_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_449_data2.jpg
# Duplicate found: trash_001_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_187_data2.jpg
# Duplicate found: trash204_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_767_data2.jpg
# Duplicate found: trash_745_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash295_data1.jpg
# Duplicate found: trash85_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_230_data2.jpg
# Duplicate found: trash_720_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash528_data1.jpg
# Duplicate found: trash611_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_754_data2.jpg
# Duplicate found: trash_081_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_17_data2.jpg
# Duplicate found: trash_660_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash556_data1.jpg
# Duplicate found: trash_461_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash693_data1.jpg
# Duplicate found: trash_440_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash12_data1.jpg
# Duplicate found: trash_714_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash246_data1.jpg
# Duplicate found: trash_171_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash134_data1.jpg
# Duplicate found: trash432_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_212_data2.jpg
# Duplicate found: trash_28_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash259_data1.jpg
# Duplicate found: trash_324_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_026_data3.jpg
# Duplicate found: trash_084_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_783_data2.jpg
# Duplicate found: trash509_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_39_data2.jpg
# Duplicate found: trash_137_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash581_data1.jpg
# Duplicate found: trash_333_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash612_data1.jpg
# Duplicate found: trash_48_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_114_data3.jpg
# Duplicate found: trash_821_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash177_data1.jpg
# Duplicate found: trash361_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_339_data2.jpg
# Duplicate found: trash_223_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash38_data1.jpg
# Duplicate found: trash_061_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_144_data2.jpg
# Duplicate found: trash_555_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash366_data1.jpg
# Duplicate found: trash_214_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash202_data1.jpg
# Duplicate found: trash662_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_432_data2.jpg
# Duplicate found: trash_140_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_049_data3.jpg
# Duplicate found: trash_163_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash679_data1.jpg
# Duplicate found: trash395_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_522_data2.jpg
# Duplicate found: trash_475_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash336_data1.jpg
# Duplicate found: trash235_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_173_data2.jpg
# Duplicate found: trash330_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_742_data2.jpg
# Duplicate found: trash_451_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_108_data3.jpg
# Duplicate found: trash183_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_728_data2.jpg
# Duplicate found: trash_109_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_152_data2.jpg
# Duplicate found: trash58_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_534_data2.jpg
# Duplicate found: trash452_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_110_data2.jpg
# Duplicate found: trash9_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_818_data2.jpg
# Duplicate found: trash_40_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash178_data1.jpg
# Duplicate found: trash229_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_656_data2.jpg
# Duplicate found: trash_94_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash257_data1.jpg
# Duplicate found: trash_4_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash410_data1.jpg
# Duplicate found: trash_266_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash411_data1.jpg
# Duplicate found: trash_781_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash293_data1.jpg
# Duplicate found: trash405_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_349_data2.jpg
# Duplicate found: trash_66_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash225_data1.jpg
# Duplicate found: trash43_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_134_data2.jpg
# Duplicate found: trash597_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_204_data2.jpg
# Duplicate found: trash_552_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash365_data1.jpg
# Duplicate found: trash_364_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_135_data3.jpg
# Duplicate found: trash_418_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash503_data1.jpg
# Duplicate found: trash_603_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash302_data1.jpg
# Duplicate found: trash_616_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash352_data1.jpg
# Duplicate found: trash669_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_459_data2.jpg
# Duplicate found: trash_336_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash2_data1.jpg
# Duplicate found: trash_707_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash429_data1.jpg
# Duplicate found: trash684_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_528_data2.jpg
# Duplicate found: trash449_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_119_data2.jpg
# Duplicate found: trash_569_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash299_data1.jpg
# Duplicate found: trash_093_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_51_data2.jpg
# Duplicate found: trash637_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_464_data2.jpg
# Duplicate found: trash_506_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash112_data1.jpg
# Duplicate found: trash_120_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_653_data2.jpg
# Duplicate found: trash_553_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash46_data1.jpg
# Duplicate found: trash_002_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_503_data2.jpg
# Duplicate found: trash539_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_815_data2.jpg
# Duplicate found: trash128_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_304_data2.jpg
# Duplicate found: trash_12_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash34_data1.jpg
# Duplicate found: trash226_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_509_data2.jpg
# Duplicate found: trash1_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_22_data2.jpg
# Duplicate found: trash272_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_250_data2.jpg
# Duplicate found: trash675_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_438_data2.jpg
# Duplicate found: trash_641_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash642_data1.jpg
# Duplicate found: trash527_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_267_data2.jpg
# Duplicate found: trash_075_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_486_data2.jpg
# Duplicate found: trash_82_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_024_data3.jpg
# Duplicate found: trash_040_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_3_data2.jpg
# Duplicate found: trash439_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_668_data2.jpg
# Duplicate found: trash_389_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash517_data1.jpg
# Duplicate found: trash_104_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_123_data2.jpg
# Duplicate found: trash_725_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash318_data1.jpg
# Duplicate found: trash243_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_802_data2.jpg
# Duplicate found: trash_766_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash566_data1.jpg
# Duplicate found: trash_064_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_523_data2.jpg
# Duplicate found: trash_813_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_055_data3.jpg
# Duplicate found: trash_706_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_366_data2.jpg
# Duplicate found: trash_787_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash461_data1.jpg
# Duplicate found: trash374_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_518_data2.jpg
# Duplicate found: trash144_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_551_data2.jpg
# Duplicate found: trash309_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_417_data2.jpg
# Duplicate found: trash_087_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_428_data2.jpg
# Duplicate found: trash_401_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash131_data1.jpg
# Duplicate found: trash683_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_445_data2.jpg
# Duplicate found: trash118_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_372_data2.jpg
# Duplicate found: trash372_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_470_data2.jpg
# Duplicate found: trash_761_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash574_data1.jpg
# Duplicate found: trash90_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_798_data2.jpg
# Duplicate found: trash123_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_811_data2.jpg
# Duplicate found: trash_377_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash466_data1.jpg
# Duplicate found: trash168_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_23_data2.jpg
# Duplicate found: trash_591_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash494_data1.jpg
# Duplicate found: trash_744_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash251_data1.jpg
# Duplicate found: trash321_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_669_data2.jpg
# Duplicate found: trash18_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_248_data2.jpg
# Duplicate found: trash_195_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash57_data1.jpg
# Duplicate found: trash496_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_799_data2.jpg
# Duplicate found: trash_376_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash356_data1.jpg
# Duplicate found: trash274_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_627_data2.jpg
# Duplicate found: trash191_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_20_data2.jpg
# Duplicate found: trash_27_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash116_data1.jpg
# Duplicate found: trash537_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_731_data2.jpg
# Duplicate found: trash_661_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash200_data1.jpg
# Duplicate found: trash_593_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash83_data1.jpg
# Duplicate found: trash198_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_299_data2.jpg
# Duplicate found: trash_197_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_100_data3.jpg
# Duplicate found: trash311_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_594_data2.jpg
# Duplicate found: trash5_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_400_data2.jpg
# Duplicate found: trash171_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_307_data2.jpg
# Duplicate found: trash127_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_801_data2.jpg
# Duplicate found: trash_732_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash137_data1.jpg
# Duplicate found: trash147_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_146_data2.jpg
# Duplicate found: trash7_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_115_data2.jpg
# Duplicate found: trash_181_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash197_data1.jpg
# Duplicate found: trash_375_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash434_data1.jpg
# Duplicate found: trash_096_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_476_data2.jpg
# Duplicate found: trash_325_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash3_data1.jpg
# Duplicate found: trash451_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_568_data2.jpg
# Duplicate found: trash_657_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_133_data3.jpg
# Duplicate found: trash_371_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash654_data1.jpg
# Duplicate found: trash_726_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash525_data1.jpg
# Duplicate found: trash338_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_786_data2.jpg
# Duplicate found: trash559_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash254_data1.jpg
# Duplicate found: trash97_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_148_data2.jpg
# Duplicate found: trash25_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_814_data2.jpg
# Duplicate found: trash_311_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_006_data3.jpg
# Duplicate found: trash273_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_629_data2.jpg
# Duplicate found: trash261_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_618_data2.jpg
# Duplicate found: trash382_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_71_data2.jpg
# Duplicate found: trash_149_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash307_data1.jpg
# Duplicate found: trash124_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_562_data2.jpg
# Duplicate found: trash_331_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash277_data1.jpg
# Duplicate found: trash_271_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash107_data1.jpg
# Duplicate found: trash_588_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash103_data1.jpg
# Duplicate found: trash_353_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash262_data1.jpg
# Duplicate found: trash19_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_295_data2.jpg
# Duplicate found: trash_395_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_018_data3.jpg
# Duplicate found: trash313_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_663_data2.jpg
# Duplicate found: trash_477_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_053_data3.jpg
# Duplicate found: trash_147_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash26_data1.jpg
# Duplicate found: trash_762_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash368_data1.jpg
# Duplicate found: trash481_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_739_data2.jpg
# Duplicate found: trash_526_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash396_data1.jpg
# Duplicate found: trash354_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_129_data2.jpg
# Duplicate found: trash238_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_366_data2.jpg
# Duplicate found: trash_76_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash694_data1.jpg
# Duplicate found: trash_777_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash628_data1.jpg
# Duplicate found: trash_427_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_038_data3.jpg
# Duplicate found: trash_176_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash60_data1.jpg
# Duplicate found: trash348_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_373_data2.jpg
# Duplicate found: trash_634_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash479_data1.jpg
# Duplicate found: trash676_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_218_data2.jpg
# Duplicate found: trash491_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_705_data2.jpg
# Duplicate found: trash_151_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash51_data1.jpg
# Duplicate found: trash_572_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash617_data1.jpg
# Duplicate found: trash151_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_539_data2.jpg
# Duplicate found: trash_625_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_051_data3.jpg
# Duplicate found: trash553_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_229_data2.jpg
# Duplicate found: trash_044_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_550_data2.jpg
# Duplicate found: trash398_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_677_data2.jpg
# Duplicate found: trash_063_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_626_data2.jpg
# Duplicate found: trash588_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_296_data2.jpg
# Duplicate found: trash_308_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash121_data1.jpg
# Duplicate found: trash_330_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash407_data1.jpg
# Duplicate found: trash92_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_496_data2.jpg
# Duplicate found: trash_213_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_088_data3.jpg
# Duplicate found: trash532_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_460_data2.jpg
# Duplicate found: trash276_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_132_data2.jpg
# Duplicate found: trash_103_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash328_data1.jpg
# Duplicate found: trash_505_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash182_data1.jpg
# Duplicate found: trash_004_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_70_data2.jpg
# Duplicate found: trash224_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_540_data2.jpg
# Duplicate found: trash143_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_161_data2.jpg
# Duplicate found: trash169_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_126_data2.jpg
# Duplicate found: trash467_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_63_data2.jpg
# Duplicate found: trash516_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_617_data2.jpg
# Duplicate found: trash255_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_738_data2.jpg
# Duplicate found: trash636_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_165_data2.jpg
# Duplicate found: trash543_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_369_data2.jpg
# Duplicate found: trash647_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_716_data2.jpg
# Duplicate found: trash_713_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash390_data1.jpg
# Duplicate found: trash688_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_541_data2.jpg
# Duplicate found: trash_782_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash153_data1.jpg
# Duplicate found: trash_109_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash82_data1.jpg
# Duplicate found: trash_262_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash286_data1.jpg
# Duplicate found: trash417_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_546_data2.jpg
# Duplicate found: trash_344_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_097_data3.jpg
# Duplicate found: trash_409_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_033_data3.jpg
# Duplicate found: trash138_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_693_data2.jpg
# Duplicate found: trash_702_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_041_data3.jpg
# Duplicate found: trash45_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_347_data2.jpg
# Duplicate found: trash_319_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_048_data3.jpg
# Duplicate found: trash_357_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_066_data3.jpg
# Duplicate found: trash_655_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash678_data1.jpg
# Duplicate found: trash_722_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_089_data3.jpg
# Duplicate found: trash680_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_263_data2.jpg
# Duplicate found: trash22_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_380_data2.jpg
# Duplicate found: trash687_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_768_data2.jpg
# Duplicate found: trash_466_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash583_data1.jpg
# Duplicate found: trash_448_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash499_data1.jpg
# Duplicate found: trash_527_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash427_data1.jpg
# Duplicate found: trash_054_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_102_data2.jpg
# Duplicate found: trash_771_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash89_data1.jpg
# Duplicate found: trash283_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_8_data2.jpg
# Duplicate found: trash443_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_682_data2.jpg
# Duplicate found: trash492_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_80_data2.jpg
# Duplicate found: trash510_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_59_data2.jpg
# Duplicate found: trash_456_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_029_data3.jpg
# Duplicate found: trash619_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_630_data2.jpg
# Duplicate found: trash_701_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_119_data3.jpg
# Duplicate found: trash_805_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash120_data1.jpg
# Duplicate found: trash_46_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash608_data1.jpg
# Duplicate found: trash_642_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash248_data1.jpg
# Duplicate found: trash_354_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash565_data1.jpg
# Duplicate found: trash_558_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash422_data1.jpg
# Duplicate found: trash_130_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_435_data2.jpg
# Duplicate found: trash346_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_188_data2.jpg
# Duplicate found: trash_637_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash455_data1.jpg
# Duplicate found: trash_789_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash489_data1.jpg
# Duplicate found: trash181_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_819_data2.jpg
# Duplicate found: trash_711_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash133_data1.jpg
# Duplicate found: trash_124_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_270_data2.jpg
# Duplicate found: trash_529_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash33_data1.jpg
# Duplicate found: trash618_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_517_data2.jpg
# Duplicate found: trash301_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_366_data2.jpg
# Duplicate found: trash333_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_62_data2.jpg
# Duplicate found: trash_211_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash383_data1.jpg
# Duplicate found: trash_93_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash397_data1.jpg
# Duplicate found: trash_685_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash86_data1.jpg
# Duplicate found: trash_092_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_620_data2.jpg
# Duplicate found: trash_632_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash193_data1.jpg
# Duplicate found: trash_154_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash573_data1.jpg
# Duplicate found: trash_83_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash420_data1.jpg
# Duplicate found: trash146_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_338_data2.jpg
# Duplicate found: trash666_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_573_data2.jpg
# Duplicate found: trash568_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_717_data2.jpg
# Duplicate found: trash_177_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash154_data1.jpg
# Duplicate found: trash_005_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_35_data2.jpg
# Duplicate found: trash105_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_433_data2.jpg
# Duplicate found: trash_100_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash93_data1.jpg
# Duplicate found: trash_700_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash30_data1.jpg
# Duplicate found: trash428_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_502_data2.jpg
# Duplicate found: trash_465_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash220_data1.jpg
# Duplicate found: trash6_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_225_data2.jpg
# Duplicate found: trash_293_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash334_data1.jpg
# Duplicate found: trash_511_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash485_data1.jpg
# Duplicate found: trash_326_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash187_data1.jpg
# Duplicate found: trash322_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_310_data2.jpg
# Duplicate found: trash_543_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_070_data3.jpg
# Duplicate found: trash_606_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_082_data3.jpg
# Duplicate found: trash_386_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash68_data1.jpg
# Duplicate found: trash263_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_406_data2.jpg
# Duplicate found: trash353_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_290_data2.jpg
# Duplicate found: trash_122_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash265_data1.jpg
# Duplicate found: trash602_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_196_data2.jpg
# Duplicate found: trash_650_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash585_data1.jpg
# Duplicate found: trash_390_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash232_data1.jpg
# Duplicate found: trash_638_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_011_data3.jpg
# Duplicate found: trash44_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_9_data2.jpg
# Duplicate found: trash_199_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash671_data1.jpg
# Duplicate found: trash358_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_421_data2.jpg
# Duplicate found: trash_566_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash444_data1.jpg
# ...
# Duplicate found: trash_434_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash630_data1.jpg
# Duplicate found: trash_11_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash10_data1.jpg
# Duplicate found: trash56_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_718_data2.jpg
# Duplicate found: trash_189_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash649_data1.jpg
# Duplicate found: trash_351_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_146_data2.jpg
# Duplicate found: trash_774_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash104_data1.jpg
# Duplicate found: trash531_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_589_data2.jpg
# Duplicate found: trash_590_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash308_data1.jpg
# Duplicate found: trash595_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_54_data2.jpg
# Duplicate found: trash_808_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash447_data1.jpg
# Duplicate found: trash223_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_628_data2.jpg
# Duplicate found: trash526_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_822_data2.jpg
# Duplicate found: trash_563_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_127_data3.jpg
# Duplicate found: trash_012_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_135_data2.jpg
# Duplicate found: trash_556_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash192_data1.jpg
# Duplicate found: trash_439_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_090_data3.jpg
# Duplicate found: trash402_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_462_data2.jpg
# Duplicate found: trash_131_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_586_data2.jpg
# Duplicate found: trash_175_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_073_data3.jpg
# Duplicate found: trash377_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_209_data2.jpg
# Duplicate found: trash665_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash356_data1.jpg
# Duplicate found: trash_41_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash400_data1.jpg
# Duplicate found: trash_164_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash442_data1.jpg
# Duplicate found: trash32_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_153_data2.jpg
# Duplicate found: trash389_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_633_data2.jpg
# Duplicate found: trash_804_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash258_data1.jpg
# Duplicate found: trash521_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_244_data2.jpg
# Duplicate found: trash_484_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_030_data3.jpg
# Duplicate found: trash_170_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash284_data1.jpg
# Duplicate found: trash_749_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash130_data1.jpg
# Duplicate found: trash98_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_322_data2.jpg
# Duplicate found: trash_190_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash102_data1.jpg
# Duplicate found: trash216_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_825_data2.jpg
# Duplicate found: trash_156_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash240_data1.jpg
# Duplicate found: trash506_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_605_data2.jpg
# Duplicate found: trash_697_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash646_data1.jpg
# Duplicate found: trash_84_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_117_data3.jpg
# Duplicate found: trash_317_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash399_data1.jpg
# Duplicate found: trash195_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_231_data2.jpg
# Duplicate found: trash_453_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_136_data3.jpg
# Duplicate found: trash493_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_664_data2.jpg
# Duplicate found: trash_052_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_471_data2.jpg
# Duplicate found: trash555_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_29_data2.jpg
# Duplicate found: trash_365_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash63_data1.jpg
# Duplicate found: trash230_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_112_data2.jpg
# Duplicate found: trash_37_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_112_data3.jpg
# Duplicate found: trash351_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_832_data2.jpg
# Duplicate found: trash_795_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash15_data1.jpg
# Duplicate found: trash596_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_25_data2.jpg
# Duplicate found: trash355_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_408_data2.jpg
# Duplicate found: trash289_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_645_data2.jpg
# Duplicate found: trash_489_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash152_data1.jpg
# Duplicate found: trash159_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_800_data2.jpg
# Duplicate found: trash_172_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash167_data1.jpg
# Duplicate found: trash_315_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_123_data3.jpg
# Duplicate found: trash_411_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash47_data1.jpg
# Duplicate found: trash511_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_473_data2.jpg
# Duplicate found: trash_644_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash339_data1.jpg
# Duplicate found: trash_680_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash113_data1.jpg
# Duplicate found: trash470_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_582_data2.jpg
# Duplicate found: trash337_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_596_data2.jpg
# Duplicate found: trash270_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_675_data2.jpg
# Duplicate found: trash280_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_599_data2.jpg
# Duplicate found: trash119_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_52_data2.jpg
# Duplicate found: trash643_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_602_data2.jpg
# Duplicate found: trash_468_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_017_data3.jpg
# Duplicate found: trash_110_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_42_data2.jpg
# Duplicate found: trash35_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_755_data2.jpg
# Duplicate found: trash_695_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash415_data1.jpg
# Duplicate found: trash209_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_681_data2.jpg
# Duplicate found: trash375_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_547_data2.jpg
# Duplicate found: trash_33_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash436_data1.jpg
# Duplicate found: trash633_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_549_data2.jpg
# Duplicate found: trash_076_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_222_data2.jpg
# Duplicate found: trash27_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_128_data2.jpg
# Duplicate found: trash_507_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash625_data1.jpg
# Duplicate found: trash_769_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash600_data1.jpg
# Duplicate found: trash94_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_145_data2.jpg
# Duplicate found: trash_429_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash349_data1.jpg
# Duplicate found: trash_425_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash497_data1.jpg
# Duplicate found: trash_085_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_600_data2.jpg
# Duplicate found: trash373_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_180_data2.jpg
# Duplicate found: trash_651_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_071_data3.jpg
# Duplicate found: trash_649_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash691_data1.jpg
# Duplicate found: trash_53_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash271_data1.jpg
# Duplicate found: trash_405_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash686_data1.jpg
# Duplicate found: trash_806_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash190_data1.jpg
# Duplicate found: trash364_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_21_data2.jpg
# Duplicate found: trash_571_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash408_data1.jpg
# Duplicate found: trash231_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_90_data2.jpg
# Duplicate found: trash189_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_162_data2.jpg
# Duplicate found: trash645_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_92_data2.jpg
# Duplicate found: trash150_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_215_data2.jpg
# Duplicate found: trash_679_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_014_data3.jpg
# Duplicate found: trash_624_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash601_data1.jpg
# Duplicate found: trash125_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_776_data2.jpg
# Duplicate found: trash_607_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash477_data1.jpg
# Duplicate found: trash_639_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash419_data1.jpg
# Duplicate found: trash_126_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_7_data2.jpg
# Duplicate found: trash340_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_816_data2.jpg
# Duplicate found: trash_399_data2.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_043_data3.jpg
# Duplicate found: trash545_data1.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_676_data2.jpg
# Duplicate found: trash_069_data3.jpg is a duplicate of /home/namdng/Documents/linhtinh/garbage_classifier/data/merged_filter_dups/trash/trash_485_data2.jpg

# %%
# check hashing algo
# two very similar images
img1_path = "data/check_imghash/MirOx.png"
img2_path = "data/check_imghash/e3FsG.png"

import imagehash

hash1 = imagehash.phash(Image.open(img1_path))
hash2 = imagehash.phash(Image.open(img2_path))

print(hash1 - hash2)
# Out:
# 4

# %% [markdown]
# ## Add-on codes

# %% [markdown]
# ### Extract data from YOLO dataset

# %%
import os

SRC_PATH = "/home/namdng/Documents/linhtinh/garbage_classifier/GARBAGE CLASSIFICATION 3.v2-gc1.coco/valid"
YOLO_DATA_PATH = "data/yolo_data"
os.makedirs(YOLO_DATA_PATH, exist_ok=True)

yolo_class_names = ["BIODEGRADABLE", "CARDBOARD", "GLASS", "METAL", "PAPER", "PLASTIC"]
yolo_class_names = [name.lower() for name in yolo_class_names]
# create each folder
for class_name in yolo_class_names:
    os.makedirs(os.path.join(YOLO_DATA_PATH, class_name), exist_ok=True)

# copy images to corresponding folder
for file_name in os.listdir(SRC_PATH):
    if file_name.endswith(".jpg"):
        file_name_contain_class = file_name.split("_")[0].lower()
        # choose which class to copy to
        choosen_class = ""
        for class_name in yolo_class_names:
            if class_name in file_name_contain_class:
                choosen_class = class_name
                break

        if choosen_class != "":
            shutil.copy(os.path.join(SRC_PATH, file_name), os.path.join(YOLO_DATA_PATH, choosen_class, file_name))
        else:
            print(f"Cannot find class for {file_name}")
